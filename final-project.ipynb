# %%
import pandas as pd

# %%
happiness = pd.read_csv("happiness.csv")
development = pd.read_csv("development.csv")

happiness.head()
# Out:
#     Country  Score  GDP per capita
# 0  Bulgaria    5.1             1.2
# 1   Germany    6.8             2.5
# 2    France    6.7             2.3
# 3       USA    7.0             3.0
# 4     Japan    6.1             2.2

# %%
development = pd.read_csv("development.csv")

development.head()
data = pd.merge(happiness, development, on="Country")

data.head()
data = data.dropna()
data
# Out:
#      Country  Score  GDP per capita  Life Expectancy
# 0   Bulgaria    5.1             1.2               75
# 1    Germany    6.8             2.5               81
# 2     France    6.7             2.3               82
# 3        USA    7.0             3.0               79
# 4      Japan    6.1             2.2               84
# 5      India    4.0             0.9               70
# 6     Brazil    6.3             1.8               75
# 7     Canada    7.2             3.1               83
# 8  Australia    7.3             3.2               84
# 9      Italy    6.5             2.0               83

# %%
import matplotlib.pyplot as plt

plt.scatter(data["GDP per capita"], data["Score"])
plt.xlabel("GDP per capita")
plt.ylabel("Happiness Score")
plt.title("GDP vs Happiness")
plt.show()
import seaborn as sns

sns.heatmap(data.corr(numeric_only=True), annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-47c7ff43138c> in <module>
#       8 import seaborn as sns
#       9
# ---> 10 sns.heatmap(data.corr(numeric_only=True), annot=True)
#      11 plt.title("Correlation Matrix")
#      12 plt.show()
#
# TypeError: corr() got an unexpected keyword argument 'numeric_only'

# %%
import seaborn as sns

sns.heatmap(data.corr(numeric_only=True), annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f04a51d23e1b> in <module>
#       1 import seaborn as sns
#       2
# ----> 3 sns.heatmap(data.corr(numeric_only=True), annot=True)
#       4 plt.title("Correlation Matrix")
#       5 plt.show()
#
# TypeError: corr() got an unexpected keyword argument 'numeric_only'

# %%
data.corr(numeric_only=True)
corr = data["GDP per capita"].corr(data["Score"])
print("Correlation between GDP and Happiness:", corr)

# %% [markdown]
# $$
# r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}}
# $$
